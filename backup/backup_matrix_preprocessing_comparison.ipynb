# %% [markdown]
# # Setup

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import numpy as np
import pandas as pd
import modellib.io as io
import matplotlib.pyplot as plt

from numpy.linalg import cond
from matrixkit import preconditioning as prec

# %% [markdown]
# # Load original matrices, true block starts and predicted block starts from CNN and SVB Algorithm

# %%
# Reading original test matrices 
test_matrices = np.load('data/matrices/test_matrices_64x64_200.npy')

# Reading block start indicators
_, true_blocks = io.read_from_hdf5('data/datasets/test_dataset_64_200.h5')
cnn_blocks = np.load('data/blockstarts/cnn_predictions.npy')
svb_blocks = np.load('data/blockstarts/svb_predictions_max_16.npy')
gcn_blocks = np.load('data/blockstarts/gcn_predictions.npy')

# Verify Shapes
print(f'Test Matrices Shape: {test_matrices.shape}')
print(f'True Blockstarts Shape: {true_blocks.shape}')
print(f'CNN Predictions Shape: {cnn_blocks.shape}')
print(f'SVB Predictions Shape: {svb_blocks.shape}')
print(f'GCN Predictions Shape: {gcn_blocks.shape}')
# Out:
# Test Matrices Shape: (200, 64, 64)
# True Blockstarts Shape: (200, 64)
# CNN Predictions Shape: (200, 64)
# SVB Predictions Shape: (200, 64)
# GCN Predictions Shape: (200, 64)

# %% [markdown]
# # Create Preconditioner from true and predicted block starts
# ### 1. Generate variants of the original matrix data as inversion targets (i.e. 'A' in 'Ax = b')

# %%
A_orig = test_matrices
A_norm = prec.prepare_matrix(A_orig, mapping_type='minmax')
A_flip = prec.prepare_matrix(A_orig, mapping_type='flip')
A_flip_norm = prec.prepare_matrix(A_orig, mapping_type='flip_norm')
A_shift = prec.prepare_matrix(A_orig, mapping_type='shift')
A_shift_norm = prec.prepare_matrix(A_orig, mapping_type='shift_norm')

# %%
# Calculate condition numbers for each method
def calculate_condition_numbers(matrices):
    return [cond(matrix) for matrix in matrices]

# Calculate condition numbers for each method
cond_orig = calculate_condition_numbers(A_orig)
cond_norm = calculate_condition_numbers(A_norm)
cond_flip = calculate_condition_numbers(A_flip)
cond_flip_norm = calculate_condition_numbers(A_flip_norm)
cond_shift = calculate_condition_numbers(A_shift)
cond_shift_norm = calculate_condition_numbers(A_shift_norm)

# Plot condition numbers
plt.figure(figsize=(10, 6))
plt.plot(cond_orig, label='Original Matrix')
plt.plot(cond_norm, label='Prepared Matrix (minmax normalised)')
plt.plot(cond_flip, label='Prepared Matrix (flipped)')
plt.plot(cond_flip_norm, label='Prepared Matrix (flipped + normalised)')
plt.plot(cond_shift, label='Prepared Matrix (shifted)')
plt.plot(cond_shift_norm, label='Prepared Matrix (shifted + normalised)')
plt.xlabel('Matrix Index')
plt.ylabel('Condition Number')
plt.title('Condition Numbers of Original and Prepared Matrices')
plt.legend()
# plt.yscale('log')  # Added log scale for better visibility
plt.tight_layout()
plt.show()

# Scatterplot 
plt.figure(figsize=(14, 6))
plt.scatter(range(len(cond_orig)), cond_orig, label='Original Matrix', marker='x')
plt.scatter(range(len(cond_norm)), cond_norm, label='Prepared Matrix (minmax normalised)', marker='s')
plt.scatter(range(len(cond_flip)), cond_flip, label='Prepared Matrix (flipped)', marker='*')
plt.scatter(range(len(cond_flip_norm)), cond_flip_norm, label='Prepared Matrix (flipped + normalised)', marker='o')
plt.scatter(range(len(cond_shift)), cond_shift, label='Prepared Matrix (shifted)', marker='+')
plt.scatter(range(len(cond_shift_norm)), cond_shift_norm, label='Prepared Matrix (shifted + normalised)', marker='.')
plt.xlabel('Matrix Index')
plt.ylabel('Condition Number (log scale)')
plt.gca().set_yscale('log')
plt.title('Condition Numbers of Original and Prepared Matrices')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Create a DataFrame for easy plotting and analysis
df = pd.DataFrame({
    'Original': cond_orig,
    'Normalised': cond_norm,
    'Flipped': cond_flip,
    'Flipped + Normalised': cond_flip_norm,
    'Shifted': cond_shift,
    'Shifted + Normalised': cond_shift_norm
})

# Calculate statistics
stats = df.agg(['mean', 'median', 'min', 'max', 'std']).T
stats['improvement'] = (stats['mean'] - stats.loc['Original', 'mean']) / stats.loc['Original', 'mean'] * 100 * -1 # Calculate improvement in percentage

# Print summary statistics
print(stats.to_string())
# Out:
#                              mean       median         min            max           std  improvement
# Original              3576.480713   586.016479  115.035286  263269.718750  20455.035156    -0.000000
# Normalised            1950.931763   566.987305  159.084396   57215.328125   6088.224609    45.451077
# Flipped               1845.928467   471.344482   84.779854  153495.859375  10960.286133    48.387016
# Flipped + Normalised  1950.931763   566.987305  159.084396   57215.328125   6088.224609    45.451077
# Shifted               6144.447266  2098.647949  476.923065  106196.968750  13482.469727   -71.801498
# Shifted + Normalised  1950.931763   566.987305  159.084396   57215.328125   6088.224609    45.451077

# %%
# Plot summary statistics
plt.figure(figsize=(10, 6))
plt.bar(stats.index, stats['improvement'], color='skyblue')
plt.axhline(0, color='black', linewidth=1)
plt.xlabel('Preparation Method')
plt.ylabel('Improvement (%)')
plt.title('Improvement in Condition Number by Preparation Method')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Invert Blocks (ensure non-singularity)

# %%
# Using True block starts from different methods and Matrices (with different preprocessing methods, optional)
precs_true = prec.generate_block_jacobi_preconditioner(A_orig, true_blocks)
precs_cnn = prec.generate_block_jacobi_preconditioner(A_orig, cnn_blocks)
precs_gcn = prec.generate_block_jacobi_preconditioner(A_orig, gcn_blocks)
precs_svb = prec.generate_block_jacobi_preconditioner(A_orig, svb_blocks)

precs_true_norm = prec.generate_block_jacobi_preconditioner(A_norm, true_blocks)
precs_true_flip = prec.generate_block_jacobi_preconditioner(A_flip, true_blocks)
precs_true_flip_norm = prec.generate_block_jacobi_preconditioner(A_flip_norm, true_blocks)
precs_true_shift_norm = prec.generate_block_jacobi_preconditioner(A_shift_norm, true_blocks)

b = np.ones((test_matrices.shape[0], A_orig.shape[1]))

# %% [markdown]
# # Run GMRES Solver:
# ### With and Without Preconditioner from True and Predcited Block Starts
#     - With original Matrices
#     - With normalised Matrices
#     - With flipped Matrices
#     - With flipped and normalised Matrices
#     - With shifted Matrices
#     - With shifted and normalised Matrices

# %%
# Run GMRES experiments with different preconditioners
input_matrices_list = [
    ('Original Matrices', A_orig),
    ('Normalised Matrices', A_norm),
    ('Flipped Matrices', A_flip),
    ('Flipped and Normalised Matrices', A_flip_norm),
    ('Shifted Matrices', A_shift),
    ('Shifted and Normalised Matrices', A_shift_norm)
]


preconditioners_list = [
    ('No Preconditioner', None),
    ('Prec from True Block Starts', precs_true),
    ('Prec from CNN Block Starts', precs_cnn),
    ('Prec from GCN Block Starts', precs_gcn),
    ('Prec from SVB Block Starts', precs_svb)    
]



results_df = prec.run_gmres_experiments(input_matrices_list, preconditioners_list, b)
prec.print_results_table(results_df)
prec.plot_results(results_df)
# Out:
# Solving Original Matrices with No Preconditioner...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 50
#      36             results.append({
#      37                 'Matrix Type': input_name,
#      38                 'Preconditioner Type': prec_name,
#    (...)
#      45                 'Min Iterations': np.min(iters_converged)
#      46             })
#      48     return pd.DataFrame(results)
# ---> 50 results_df = run_gmres_experiments(input_matrices_list, preconditioners_list, b)
#      51 prec.print_results_table(results_df)
#      52 prec.plot_results(results_df)
#
# Cell In[25], line 28, in run_gmres_experiments(input_matrices_list, preconditioners_list, b)
#      26 for prec_name, preconditioner_source in preconditioners_list:
#      27     print(f'Solving {input_name} with {prec_name}...')
# ---> 28     x, info, iters, residuals = prec.solve_with_gmres_monitored(input_matrices, b, preconditioner_source)
#      30     converged = np.sum(info == 0)
#      31     total_systems = len(info)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matrixkit\preconditioning.py:153, in solve_with_gmres_monitored(matrix, b_vector, preconditioner, relative_tolerance)
#     150     run_matrix = preconditioner[k] @ matrix[k]
#     151     run_b_vector = preconditioner[k] @ b_vector[k]
# --> 153 x, info = gmres(
#     154     A=run_matrix,
#     155     b=run_b_vector,
#     156     x0=np.zeros_like(run_b_vector),
#     157     rtol=relative_tolerance,
#     158     callback=callback,
#     159     callback_type='pr_norm'
#     160 )
#     161 x_solutions[k] = x
#     162 info_array[k] = info
#
# File C:\Program Files\Python310\lib\site-packages\scipy\_lib\deprecation.py:213, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     211 extra_args = len(args) - len(all_args)
#     212 if extra_args <= 0:
# --> 213     return f(*args, **kwargs)
#     215 # extra_args > 0
#     216 args_msg = [
#     217     f"{name}={arg}"
#     218     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#     219 ]
#
# File C:\Program Files\Python310\lib\site-packages\scipy\sparse\linalg\_isolve\iterative.py:785, in gmres(A, b, x0, tol, restart, maxiter, M, callback, restrt, atol, callback_type, rtol)
#     783 h0 = np.linalg.norm(w)
#     784 for k in range(col+1):
# --> 785     tmp = dotprod(v[k, :], w)
#     786     h[col, k] = tmp
#     787     w -= tmp*v[k, :]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Compare Results

# %%
pd.set_option("display.precision", 2)
results_df
# Out:
#                         Matrix Type  \
# 0                 Original Matrices
# 1                 Original Matrices
# 2                 Original Matrices
# 3                 Original Matrices
# 4                 Original Matrices
# 5                 Original Matrices
# 6               Normalised Matrices
# 7               Normalised Matrices
# 8               Normalised Matrices
# 9               Normalised Matrices
# 10              Normalised Matrices
# 11              Normalised Matrices
# 12                 Flipped Matrices
# 13                 Flipped Matrices
# 14                 Flipped Matrices
# 15                 Flipped Matrices
# 16                 Flipped Matrices
# 17                 Flipped Matrices
# 18  Flipped and Normalised Matrices
# 19  Flipped and Normalised Matrices
# 20  Flipped and Normalised Matrices
# 21  Flipped and Normalised Matrices
# 22  Flipped and Normalised Matrices
# 23  Flipped and Normalised Matrices
# 24                 Shifted Matrices
# 25                 Shifted Matrices
# 26                 Shifted Matrices
# 27                 Shifted Matrices
# 28                 Shifted Matrices
# 29                 Shifted Matrices
# 30  Shifted and Normalised Matrices
# 31  Shifted and Normalised Matrices
# 32  Shifted and Normalised Matrices
# 33  Shifted and Normalised Matrices
# 34  Shifted and Normalised Matrices
# 35  Shifted and Normalised Matrices
#
#                                   Preconditioner Type  Converged  \
# 0                                   No Preconditioner        181
# 1                         Prec from True Block Starts        190
# 2            Prec from True Block Starts (Normalised)        194
# 3               Prec from True Block Starts (Flipped)        195
# 4   Prec from True Block Starts (Flipped + Normali...        194
# 5   Prec from True Block Starts (Shifted + Normali...        194
# 6                                   No Preconditioner        178
# 7                         Prec from True Block Starts        185
# 8            Prec from True Block Starts (Normalised)        189
# 9               Prec from True Block Starts (Flipped)        197
# 10  Prec from True Block Starts (Flipped + Normali...        189
# 11  Prec from True Block Starts (Shifted + Normali...        189
# 12                                  No Preconditioner        186
# 13                        Prec from True Block Starts        196
# 14           Prec from True Block Starts (Normalised)        196
# 15              Prec from True Block Starts (Flipped)        172
# 16  Prec from True Block Starts (Flipped + Normali...        196
# 17  Prec from True Block Starts (Shifted + Normali...        196
# 18                                  No Preconditioner        178
# 19                        Prec from True Block Starts        185
# 20           Prec from True Block Starts (Normalised)        189
# 21              Prec from True Block Starts (Flipped)        197
# 22  Prec from True Block Starts (Flipped + Normali...        189
# 23  Prec from True Block Starts (Shifted + Normali...        189
# 24                                  No Preconditioner        196
# 25                        Prec from True Block Starts        200
# 26           Prec from True Block Starts (Normalised)        200
# 27              Prec from True Block Starts (Flipped)        200
# 28  Prec from True Block Starts (Flipped + Normali...        200
# 29  Prec from True Block Starts (Shifted + Normali...        200
# 30                                  No Preconditioner        178
# 31                        Prec from True Block Starts        185
# 32           Prec from True Block Starts (Normalised)        189
# 33              Prec from True Block Starts (Flipped)        197
# 34  Prec from True Block Starts (Flipped + Normali...        189
# 35  Prec from True Block Starts (Shifted + Normali...        189
#
#     Total Systems  Percent Converged  Mean Iterations  Median Iterations  \
# 0             200               90.5          3537.59             1947.0
# 1             200               95.0           902.37              118.0
# 2             200               97.0           651.72              109.5
# 3             200               97.5           539.84              117.0
# 4             200               97.0           651.72              109.5
# 5             200               97.0           651.72              109.5
# 6             200               89.0          3356.03             1621.5
# 7             200               92.5          1112.80              106.0
# 8             200               94.5           842.29               96.0
# 9             200               98.5           359.70               86.0
# 10            200               94.5           842.29               96.0
# 11            200               94.5           842.29               96.0
# 12            200               93.0          3056.43             1629.0
# 13            200               98.0           576.91               95.0
# 14            200               98.0           523.08               93.5
# 15            200               86.0          2032.96              120.0
# 16            200               98.0           523.08               93.5
# 17            200               98.0           523.08               93.5
# 18            200               89.0          3356.03             1621.5
# 19            200               92.5          1112.80              106.0
# 20            200               94.5           842.29               96.0
# 21            200               98.5           359.70               86.0
# 22            200               94.5           842.29               96.0
# 23            200               94.5           842.29               96.0
# 24            200               98.0          1218.36              367.5
# 25            200              100.0             4.62                5.0
# 26            200              100.0             4.53                5.0
# 27            200              100.0             4.79                5.0
# 28            200              100.0             4.53                5.0
# 29            200              100.0             4.53                5.0
# 30            200               89.0          3356.03             1621.5
# 31            200               92.5          1112.80              106.0
# 32            200               94.5           842.29               96.0
# 33            200               98.5           359.70               86.0
# 34            200               94.5           842.29               96.0
# 35            200               94.5           842.29               96.0
#
#     Max Iterations  Min Iterations
# 0            12800             168
# 1            12800              20
# 2            12800              18
# 3            12800              19
# 4            12800              18
# 5            12800              18
# 6            12800             159
# 7            12800              18
# 8            12800              19
# 9            12800              19
# 10           12800              19
# 11           12800              19
# 12           12800             143
# 13           12800              18
# 14           12800              19
# 15           12800              18
# 16           12800              19
# 17           12800              19
# 18           12800             159
# 19           12800              18
# 20           12800              19
# 21           12800              19
# 22           12800              19
# 23           12800              19
# 24           12800              40
# 25              15               2
# 26              14               2
# 27              36               2
# 28              14               2
# 29              14               2
# 30           12800             159
# 31           12800              18
# 32           12800              19
# 33           12800              19
# 34           12800              19
# 35           12800              19
